# %% [markdown]
# # Step 3 - Quanvolutional Neural Networks
# - https://pennylane.ai/qml/demos/tutorial_quanvolution/
#
# - This notebook uses quantum circuits to preprocess image data that are then fed into a custom keras model to be trained
#   * load data
#   * preprocess images
#   * build model and train with quantum preprocessing images
#   * build model and train with original images
#   * compare results

# %%
#imports
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# 2024-10-17 05:27:05.006986: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-17 05:27:05.014816: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-17 05:27:05.040162: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-17 05:27:05.069214: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-17 05:27:05.075507: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-17 05:27:05.098586: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-17 05:27:07.252457: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 100    # Size of the train dataset -> take 50 images from train dataset
n_test = 40     # Size of the test dataset -> take 30 images from test dataset

SAVE_PATH = "./"  # Data saving folder
PREPROCESS = False           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(42)           # Seed for NumPy random number generator
tf.random.set_seed(42)       # Seed for TensorFlow random number generator

# %%
# Load dataset
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# %%
# what does our dataset look like?
print ("shape train images: ", train_images.shape)
print ("shape of train labels: ", train_labels.shape)
# Out:
# shape train images:  (60000, 28, 28)
# shape of train labels:  (60000,)

# %%
# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1 -> needed for angle encoding
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %%
# Quantum and classical nodes
dev = qml.device("default.qubit", wires=4)

# %% [markdown]
# ## Construct quanvolutional ansatz

# %%
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values -> AngleEncoding
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
# print one circuit 
print(qml.draw(circuit, expansion_strategy="device")([0.1,0.2,0.3,0.4]))
# Out:
# 0: ──RY(0.31)──────────────────────────────────┤  <Z>
# 1: ──RY(0.63)──RY(1.15)─╭●─────────────────────┤  <Z>
# 2: ──RY(0.94)──RX(4.90)─│───RZ(3.75)──RX(2.80)─┤  <Z>
# 3: ──RY(1.26)───────────╰X─────────────────────┤  <Z>

# %%
# Define quanvolutional scheme
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %% [markdown]
# ## Quantum Preprocessing of dataset

# %%
# now it's time to preprocess the images we got with our quantum circuit
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")

# %%
n_samples = 8
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Build Keras model: ADAM-optimizer and crossentropy

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# ## Instantiate Optimizer and start training

# %%
# model with quantum test images
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 25/25 - 1s - 40ms/step - accuracy: 0.1400 - loss: 2.4195 - val_accuracy: 0.3500 - val_loss: 1.9447
# Epoch 2/30
# 25/25 - 0s - 8ms/step - accuracy: 0.4800 - loss: 1.6613 - val_accuracy: 0.6000 - val_loss: 1.5035
# Epoch 3/30
# 25/25 - 0s - 7ms/step - accuracy: 0.8000 - loss: 1.1181 - val_accuracy: 0.6500 - val_loss: 1.2762
# Epoch 4/30
# 25/25 - 0s - 6ms/step - accuracy: 0.8900 - loss: 0.8321 - val_accuracy: 0.7000 - val_loss: 1.1226
# Epoch 5/30
# 25/25 - 0s - 5ms/step - accuracy: 0.9200 - loss: 0.6425 - val_accuracy: 0.7000 - val_loss: 1.0203
# Epoch 6/30
# 25/25 - 0s - 5ms/step - accuracy: 0.9500 - loss: 0.5105 - val_accuracy: 0.7500 - val_loss: 0.9484
# Epoch 7/30
# 25/25 - 0s - 5ms/step - accuracy: 0.9600 - loss: 0.4153 - val_accuracy: 0.7500 - val_loss: 0.8963
# Epoch 8/30
# 25/25 - 0s - 6ms/step - accuracy: 0.9700 - loss: 0.3438 - val_accuracy: 0.7500 - val_loss: 0.8573
# Epoch 9/30
# 25/25 - 0s - 5ms/step - accuracy: 0.9900 - loss: 0.2885 - val_accuracy: 0.7500 - val_loss: 0.8273
# Epoch 10/30
# 25/25 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.2449 - val_accuracy: 0.7750 - val_loss: 0.8041
# Epoch 11/30
# 25/25 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2102 - val_accuracy: 0.7750 - val_loss: 0.7857
# Epoch 12/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1824 - val_accuracy: 0.7750 - val_loss: 0.7711
# Epoch 13/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1598 - val_accuracy: 0.7750 - val_loss: 0.7592
# Epoch 14/30
# 25/25 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1413 - val_accuracy: 0.7750 - val_loss: 0.7495
# Epoch 15/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1260 - val_accuracy: 0.7750 - val_loss: 0.7414
# Epoch 16/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1132 - val_accuracy: 0.7750 - val_loss: 0.7347
# Epoch 17/30
# 25/25 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.1024 - val_accuracy: 0.7500 - val_loss: 0.7290
# Epoch 18/30
# 25/25 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0932 - val_accuracy: 0.7500 - val_loss: 0.7242
# Epoch 19/30
# 25/25 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0852 - val_accuracy: 0.7500 - val_loss: 0.7202
# Epoch 20/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0783 - val_accuracy: 0.7500 - val_loss: 0.7167
# Epoch 21/30
# 25/25 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0723 - val_accuracy: 0.7500 - val_loss: 0.7137
# Epoch 22/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0669 - val_accuracy: 0.7250 - val_loss: 0.7112
# Epoch 23/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0622 - val_accuracy: 0.7250 - val_loss: 0.7091
# Epoch 24/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0580 - val_accuracy: 0.7250 - val_loss: 0.7073
# Epoch 25/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0543 - val_accuracy: 0.7250 - val_loss: 0.7057
# Epoch 26/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0509 - val_accuracy: 0.7250 - val_loss: 0.7044
# Epoch 27/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0478 - val_accuracy: 0.7250 - val_loss: 0.7033
# Epoch 28/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0451 - val_accuracy: 0.7250 - val_loss: 0.7024
# Epoch 29/30
# 25/25 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0425 - val_accuracy: 0.7250 - val_loss: 0.7017
# Epoch 30/30
# 25/25 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0402 - val_accuracy: 0.7250 - val_loss: 0.7011

# %%
# model with classic test images
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 25/25 - 1s - 31ms/step - accuracy: 0.1500 - loss: 2.2371 - val_accuracy: 0.2750 - val_loss: 2.0239
# Epoch 2/30
# 25/25 - 0s - 5ms/step - accuracy: 0.5400 - loss: 1.6138 - val_accuracy: 0.4750 - val_loss: 1.7160
# Epoch 3/30
# 25/25 - 0s - 4ms/step - accuracy: 0.7700 - loss: 1.2449 - val_accuracy: 0.6500 - val_loss: 1.4975
# Epoch 4/30
# 25/25 - 0s - 4ms/step - accuracy: 0.9100 - loss: 0.9866 - val_accuracy: 0.7250 - val_loss: 1.3379
# Epoch 5/30
# 25/25 - 0s - 5ms/step - accuracy: 0.9400 - loss: 0.8007 - val_accuracy: 0.7250 - val_loss: 1.2210
# Epoch 6/30
# 25/25 - 0s - 4ms/step - accuracy: 0.9400 - loss: 0.6635 - val_accuracy: 0.7250 - val_loss: 1.1340
# Epoch 7/30
# 25/25 - 0s - 5ms/step - accuracy: 0.9500 - loss: 0.5595 - val_accuracy: 0.7250 - val_loss: 1.0681
# Epoch 8/30
# 25/25 - 0s - 6ms/step - accuracy: 0.9700 - loss: 0.4785 - val_accuracy: 0.7250 - val_loss: 1.0174
# Epoch 9/30
# 25/25 - 0s - 8ms/step - accuracy: 0.9800 - loss: 0.4142 - val_accuracy: 0.7500 - val_loss: 0.9778
# Epoch 10/30
# 25/25 - 0s - 5ms/step - accuracy: 0.9900 - loss: 0.3620 - val_accuracy: 0.7500 - val_loss: 0.9465
# Epoch 11/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.3192 - val_accuracy: 0.7500 - val_loss: 0.9215
# Epoch 12/30
# 25/25 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2834 - val_accuracy: 0.7500 - val_loss: 0.9011
# Epoch 13/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2534 - val_accuracy: 0.7750 - val_loss: 0.8844
# Epoch 14/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2278 - val_accuracy: 0.7750 - val_loss: 0.8706
# Epoch 15/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2060 - val_accuracy: 0.7750 - val_loss: 0.8591
# Epoch 16/30
# 25/25 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1871 - val_accuracy: 0.7750 - val_loss: 0.8494
# Epoch 17/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1707 - val_accuracy: 0.7750 - val_loss: 0.8412
# Epoch 18/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1565 - val_accuracy: 0.7750 - val_loss: 0.8342
# Epoch 19/30
# 25/25 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.1439 - val_accuracy: 0.7750 - val_loss: 0.8283
# Epoch 20/30
# 25/25 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.1329 - val_accuracy: 0.7750 - val_loss: 0.8231
# Epoch 21/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1230 - val_accuracy: 0.7750 - val_loss: 0.8187
# Epoch 22/30
# 25/25 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.1143 - val_accuracy: 0.7750 - val_loss: 0.8149
# Epoch 23/30
# 25/25 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.1065 - val_accuracy: 0.8000 - val_loss: 0.8116
# Epoch 24/30
# 25/25 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0995 - val_accuracy: 0.8000 - val_loss: 0.8087
# Epoch 25/30
# 25/25 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0931 - val_accuracy: 0.8000 - val_loss: 0.8063
# Epoch 26/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0874 - val_accuracy: 0.8000 - val_loss: 0.8041
# Epoch 27/30
# 25/25 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0822 - val_accuracy: 0.8000 - val_loss: 0.8023
# Epoch 28/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0775 - val_accuracy: 0.8000 - val_loss: 0.8007
# Epoch 29/30
# 25/25 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0731 - val_accuracy: 0.8000 - val_loss: 0.7994
# Epoch 30/30
# 25/25 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0692 - val_accuracy: 0.8000 - val_loss: 0.7982

# %% [markdown]
# ## Evaluate results

# %%
import matplotlib.pyplot as plt

#plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# We see that with our "quantum layer" (preprocessing of data) we achieve accuracy of 0.8 with 10 epochs instead of 15 with out preprocessing.
# We also can see that loss function is steeper for the quantum case.
# (Even though training of keras model, obtimizers and CNN construction is not ideal.)
